# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-65.000, high=90.000, size=1200)
lngs = np.random.uniform(low=-180.000, high=120.000, size=1400)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d9642ae2d477899f113cd8dd08bea37c

# %%
city_url = url + "&q=" + "Los Angeles"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d9642ae2d477899f113cd8dd08bea37c&q=Los Angeles

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -118.2437, 'lat': 34.0522},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01d'}],
#  'base': 'stations',
#  'main': {'temp': 70.56,
#   'feels_like': 69.57,
#   'temp_min': 62.6,
#   'temp_max': 77,
#   'pressure': 1016,
#   'humidity': 48},
#  'visibility': 10000,
#  'wind': {'speed': 4.61, 'deg': 0},
#  'clouds': {'all': 1},
#  'dt': 1617582825,
#  'sys': {'type': 1,
#   'id': 3694,
#   'country': 'US',
#   'sunrise': 1617543335,
#   'sunset': 1617588941},
#  'timezone': -25200,
#  'id': 5368361,
#  'name': 'Los Angeles',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Los Angeles"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Get the JSON data.
lax_data = city_weather.json()

# %%
lat = lax_data["coord"]["lat"]
lng = lax_data["coord"]["lon"]
max_temp = lax_data["main"]["temp_max"]
humidity = lax_data["main"]["humidity"]
clouds = lax_data["clouds"]["all"]
wind = lax_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 34.0522 -118.2437 77 48 1 4.61

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 547

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
        city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vaini
# Processing Record 2 of Set 1 | port alfred
# Processing Record 3 of Set 1 | hilo
# Processing Record 4 of Set 1 | mar del plata
# Processing Record 5 of Set 1 | qaanaaq
# Processing Record 6 of Set 1 | hermanus
# Processing Record 7 of Set 1 | palmer
# Processing Record 8 of Set 1 | cristinapolis
# Processing Record 9 of Set 1 | todos santos
# Processing Record 10 of Set 1 | saint-augustin
# Processing Record 11 of Set 1 | atuona
# Processing Record 12 of Set 1 | ponta do sol
# Processing Record 13 of Set 1 | cayenne
# Processing Record 14 of Set 1 | port elizabeth
# Processing Record 15 of Set 1 | klaksvik
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | amuntai
# Processing Record 18 of Set 1 | kapaa
# Processing Record 19 of Set 1 | east london
# Processing Record 20 of Set 1 | azul
# Processing Record 21 of Set 1 | geraldton
# Processing Record 22 of Set 1 | khatanga
# Processing Record 23 of Set 1 | tigre
# Processing Record 24 of Set 1 | puerto ayora
# Processing Record 25 of Set 1 | mataura
# Processing Record 26 of Set 1 | jamestown
# Processing Record 27 of Set 1 | cape town
# Processing Record 28 of Set 1 | chipinge
# Processing Record 29 of Set 1 | bengkulu
# Processing Record 30 of Set 1 | tiarei
# Processing Record 31 of Set 1 | taolanaro
# Processing Record 32 of Set 1 | vestmannaeyjar
# Processing Record 33 of Set 1 | kodinsk
# Processing Record 34 of Set 1 | ushuaia
# Processing Record 35 of Set 1 | mengcheng
# Processing Record 36 of Set 1 | mahebourg
# Processing Record 37 of Set 1 | victoria
# Processing Record 38 of Set 1 | carnarvon
# Processing Record 39 of Set 1 | walvis bay
# Processing Record 40 of Set 1 | santo angelo
# Processing Record 41 of Set 1 | barentsburg
# Processing Record 42 of Set 1 | lebu
# Processing Record 43 of Set 1 | lompoc
# Processing Record 44 of Set 1 | upernavik
# Processing Record 45 of Set 1 | korla
# Processing Record 46 of Set 1 | arraial do cabo
# Processing Record 47 of Set 1 | busselton
# Processing Record 48 of Set 1 | san patricio
# Processing Record 49 of Set 1 | hithadhoo
# Processing Record 50 of Set 1 | kodiak
# Processing Record 1 of Set 2 | saint george
# Processing Record 2 of Set 2 | novyy urengoy
# Processing Record 3 of Set 2 | klerksdorp
# Processing Record 4 of Set 2 | ahuimanu
# Processing Record 5 of Set 2 | bathsheba
# Processing Record 6 of Set 2 | fairbanks
# Processing Record 7 of Set 2 | simao
# Processing Record 8 of Set 2 | puerto ayacucho
# Processing Record 9 of Set 2 | balykshi
# Processing Record 10 of Set 2 | tevaitoa
# Processing Record 11 of Set 2 | mys shmidta
# Processing Record 12 of Set 2 | saint-pierre
# Processing Record 13 of Set 2 | olafsvik
# Processing Record 14 of Set 2 | teahupoo
# Processing Record 15 of Set 2 | karkaralinsk
# Processing Record 16 of Set 2 | baixa grande
# Processing Record 17 of Set 2 | morgan city
# Processing Record 18 of Set 2 | rocha
# Processing Record 19 of Set 2 | saskylakh
# Processing Record 20 of Set 2 | nantucket
# Processing Record 21 of Set 2 | sao joao da barra
# Processing Record 22 of Set 2 | bethel
# Processing Record 23 of Set 2 | dzerzhinsk
# Processing Record 24 of Set 2 | hue
# Processing Record 25 of Set 2 | thompson
# Processing Record 26 of Set 2 | manicore
# Processing Record 27 of Set 2 | frontignan
# Processing Record 28 of Set 2 | punta arenas
# Processing Record 29 of Set 2 | volax
# Processing Record 30 of Set 2 | bilma
# Processing Record 31 of Set 2 | illoqqortoormiut
# Processing Record 32 of Set 2 | karratha
# Processing Record 33 of Set 2 | yuanping
# Processing Record 34 of Set 2 | inirida
# Processing Record 35 of Set 2 | shubarshi
# Processing Record 36 of Set 2 | iskenderun
# Processing Record 37 of Set 2 | belushya guba
# Processing Record 38 of Set 2 | umzimvubu
# Processing Record 39 of Set 2 | tarakan
# Processing Record 40 of Set 2 | quatre cocos
# Processing Record 41 of Set 2 | mana
# Processing Record 42 of Set 2 | castro
# Processing Record 43 of Set 2 | monrovia
# Processing Record 44 of Set 2 | qasigiannguit
# Processing Record 45 of Set 2 | ust-tsilma
# Processing Record 46 of Set 2 | mayo
# Processing Record 47 of Set 2 | south lake tahoe
# Processing Record 48 of Set 2 | saint-philippe
# Processing Record 49 of Set 2 | souillac
# Processing Record 50 of Set 2 | barrow
# Processing Record 1 of Set 3 | obo
# Processing Record 2 of Set 3 | hamilton
# Processing Record 3 of Set 3 | podhum
# Processing Record 4 of Set 3 | torbay
# Processing Record 5 of Set 3 | raudeberg
# Processing Record 6 of Set 3 | otatitlan
# Processing Record 7 of Set 3 | farap
# Processing Record 8 of Set 3 | attawapiskat
# Processing Record 9 of Set 3 | yumen
# Processing Record 10 of Set 3 | inhambane
# Processing Record 11 of Set 3 | mozarlandia
# Processing Record 12 of Set 3 | ancud
# Processing Record 13 of Set 3 | mount pleasant
# Processing Record 14 of Set 3 | tazovskiy
# Processing Record 15 of Set 3 | vardo
# Processing Record 16 of Set 3 | jakoruda
# Processing Record 17 of Set 3 | brae
# Processing Record 18 of Set 3 | vyartsilya
# Processing Record 19 of Set 3 | bambous virieux
# Processing Record 20 of Set 3 | bubaque
# Processing Record 21 of Set 3 | paamiut
# Processing Record 22 of Set 3 | cidreira
# Processing Record 23 of Set 3 | valley city
# Processing Record 24 of Set 3 | jacareacanga
# Processing Record 25 of Set 3 | georgetown
# Processing Record 26 of Set 3 | teguldet
# Processing Record 27 of Set 3 | chimbote
# Processing Record 28 of Set 3 | almeirim
# Processing Record 29 of Set 3 | ribeira grande
# Processing Record 30 of Set 3 | kungurtug
# Processing Record 31 of Set 3 | rafaela
# Processing Record 32 of Set 3 | gulshat
# Processing Record 33 of Set 3 | kachiry
# Processing Record 34 of Set 3 | vaitupu
# Processing Record 35 of Set 3 | gorno-chuyskiy
# Processing Record 36 of Set 3 | muborak
# Processing Record 37 of Set 3 | norman wells
# Processing Record 38 of Set 3 | pasni
# Processing Record 39 of Set 3 | fort saint john
# Processing Record 40 of Set 3 | lujan
# Processing Record 41 of Set 3 | nanortalik
# Processing Record 42 of Set 3 | isiro
# Processing Record 43 of Set 3 | aranos
# Processing Record 44 of Set 3 | longyearbyen
# Processing Record 45 of Set 3 | puerto del rosario
# Processing Record 46 of Set 3 | asosa
# Processing Record 47 of Set 3 | bridlington
# Processing Record 48 of Set 3 | albany
# Processing Record 49 of Set 3 | matay
# Processing Record 50 of Set 3 | boende
# Processing Record 1 of Set 4 | haibowan
# City not found. Skipping...
# Processing Record 2 of Set 4 | tasiilaq
# City not found. Skipping...
# Processing Record 3 of Set 4 | porto novo
# City not found. Skipping...
# Processing Record 4 of Set 4 | umba
# City not found. Skipping...
# Processing Record 5 of Set 4 | codrington
# City not found. Skipping...
# Processing Record 6 of Set 4 | burica
# City not found. Skipping...
# Processing Record 7 of Set 4 | umm kaddadah
# City not found. Skipping...
# Processing Record 8 of Set 4 | rio grande
# City not found. Skipping...
# Processing Record 9 of Set 4 | namibe
# City not found. Skipping...
# Processing Record 10 of Set 4 | haines junction
# City not found. Skipping...
# Processing Record 11 of Set 4 | carutapera
# City not found. Skipping...
# Processing Record 12 of Set 4 | fuerte olimpo
# City not found. Skipping...
# Processing Record 13 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 4 | bredasdorp
# City not found. Skipping...
# Processing Record 15 of Set 4 | bethanien
# City not found. Skipping...
# Processing Record 16 of Set 4 | winnemucca
# City not found. Skipping...
# Processing Record 17 of Set 4 | mazatlan
# City not found. Skipping...
# Processing Record 18 of Set 4 | isoka
# City not found. Skipping...
# Processing Record 19 of Set 4 | montego bay
# City not found. Skipping...
# Processing Record 20 of Set 4 | chuy
# City not found. Skipping...
# Processing Record 21 of Set 4 | porto santo
# City not found. Skipping...
# Processing Record 22 of Set 4 | adrar
# City not found. Skipping...
# Processing Record 23 of Set 4 | kapoeta
# City not found. Skipping...
# Processing Record 24 of Set 4 | kapit
# City not found. Skipping...
# Processing Record 25 of Set 4 | hailar
# City not found. Skipping...
# Processing Record 26 of Set 4 | abu dhabi
# City not found. Skipping...
# Processing Record 27 of Set 4 | valente
# City not found. Skipping...
# Processing Record 28 of Set 4 | guerrero negro
# City not found. Skipping...
# Processing Record 29 of Set 4 | sitia
# City not found. Skipping...
# Processing Record 30 of Set 4 | grand gaube
# City not found. Skipping...
# Processing Record 31 of Set 4 | lincoln
# City not found. Skipping...
# Processing Record 32 of Set 4 | allapalli
# City not found. Skipping...
# Processing Record 33 of Set 4 | qinzhou
# City not found. Skipping...
# Processing Record 34 of Set 4 | chunoyar
# City not found. Skipping...
# Processing Record 35 of Set 4 | moron
# City not found. Skipping...
# Processing Record 36 of Set 4 | tumpat
# City not found. Skipping...
# Processing Record 37 of Set 4 | astoria
# City not found. Skipping...
# Processing Record 38 of Set 4 | san quintin
# City not found. Skipping...
# Processing Record 39 of Set 4 | bonavista
# City not found. Skipping...
# Processing Record 40 of Set 4 | placido de castro
# City not found. Skipping...
# Processing Record 41 of Set 4 | dabat
# City not found. Skipping...
# Processing Record 42 of Set 4 | ladozhskaya
# City not found. Skipping...
# Processing Record 43 of Set 4 | vanderhoof
# City not found. Skipping...
# Processing Record 44 of Set 4 | sao filipe
# City not found. Skipping...
# Processing Record 45 of Set 4 | kamenka
# City not found. Skipping...
# Processing Record 46 of Set 4 | damghan
# City not found. Skipping...
# Processing Record 47 of Set 4 | saint-louis
# City not found. Skipping...
# Processing Record 48 of Set 4 | murgab
# City not found. Skipping...
# Processing Record 49 of Set 4 | faanui
# City not found. Skipping...
# Processing Record 50 of Set 4 | atoka
# City not found. Skipping...
# Processing Record 1 of Set 5 | port blair
# Processing Record 2 of Set 5 | camana
# Processing Record 3 of Set 5 | baependi
# Processing Record 4 of Set 5 | provideniya
# Processing Record 5 of Set 5 | paracuru
# Processing Record 6 of Set 5 | avarua
# Processing Record 7 of Set 5 | atar
# Processing Record 8 of Set 5 | barabai
# Processing Record 9 of Set 5 | banda aceh
# Processing Record 10 of Set 5 | okitipupa
# Processing Record 11 of Set 5 | viedma
# Processing Record 12 of Set 5 | cockburn town
# Processing Record 13 of Set 5 | diffa
# Processing Record 14 of Set 5 | talnakh
# Processing Record 15 of Set 5 | yellowknife
# Processing Record 16 of Set 5 | dikson
# Processing Record 17 of Set 5 | matale
# Processing Record 18 of Set 5 | carndonagh
# Processing Record 19 of Set 5 | lianran
# Processing Record 20 of Set 5 | shubarkuduk
# Processing Record 21 of Set 5 | roald
# Processing Record 22 of Set 5 | svrljig
# Processing Record 23 of Set 5 | iqaluit
# Processing Record 24 of Set 5 | hargeysa
# Processing Record 25 of Set 5 | barcelos
# Processing Record 26 of Set 5 | itarema
# Processing Record 27 of Set 5 | lalibela
# Processing Record 28 of Set 5 | olinda
# Processing Record 29 of Set 5 | toliary
# Processing Record 30 of Set 5 | port hardy
# Processing Record 31 of Set 5 | granville
# Processing Record 32 of Set 5 | chapais
# Processing Record 33 of Set 5 | tuktoyaktuk
# Processing Record 34 of Set 5 | bam
# Processing Record 35 of Set 5 | shitanjing
# Processing Record 36 of Set 5 | gwadar
# Processing Record 37 of Set 5 | falealupo
# Processing Record 38 of Set 5 | devils lake
# Processing Record 39 of Set 5 | lat yao
# Processing Record 40 of Set 5 | hualmay
# Processing Record 41 of Set 5 | senador guiomard
# Processing Record 42 of Set 5 | araguatins
# Processing Record 43 of Set 5 | waddan
# Processing Record 44 of Set 5 | georgiyevka
# Processing Record 45 of Set 5 | moletai
# Processing Record 46 of Set 5 | harper
# Processing Record 47 of Set 5 | vanersborg
# Processing Record 48 of Set 5 | chandur bazar
# Processing Record 49 of Set 5 | smithers
# Processing Record 50 of Set 5 | hami
# Processing Record 1 of Set 6 | ilulissat
# Processing Record 2 of Set 6 | marcona
# Processing Record 3 of Set 6 | sitka
# Processing Record 4 of Set 6 | san martin
# Processing Record 5 of Set 6 | kotri
# Processing Record 6 of Set 6 | colares
# Processing Record 7 of Set 6 | panaba
# Processing Record 8 of Set 6 | aksarka
# Processing Record 9 of Set 6 | muri
# Processing Record 10 of Set 6 | acarau
# Processing Record 11 of Set 6 | ndele
# Processing Record 12 of Set 6 | pitea
# Processing Record 13 of Set 6 | tautira
# Processing Record 14 of Set 6 | lerwick
# Processing Record 15 of Set 6 | acapulco
# Processing Record 16 of Set 6 | margate
# Processing Record 17 of Set 6 | taoudenni
# Processing Record 18 of Set 6 | awjilah
# Processing Record 19 of Set 6 | constitucion
# Processing Record 20 of Set 6 | jumla
# Processing Record 21 of Set 6 | aklavik
# Processing Record 22 of Set 6 | pisco
# Processing Record 23 of Set 6 | tarudant
# Processing Record 24 of Set 6 | saleaula
# Processing Record 25 of Set 6 | galesong
# Processing Record 26 of Set 6 | sao gabriel da cachoeira
# Processing Record 27 of Set 6 | kalmunai
# Processing Record 28 of Set 6 | new glasgow
# Processing Record 29 of Set 6 | tumannyy
# Processing Record 30 of Set 6 | klyuchi
# Processing Record 31 of Set 6 | polewali
# Processing Record 32 of Set 6 | ode
# Processing Record 33 of Set 6 | bada
# Processing Record 34 of Set 6 | lagoa
# Processing Record 35 of Set 6 | los llanos de aridane
# Processing Record 36 of Set 6 | hauterive
# Processing Record 37 of Set 6 | vila velha
# Processing Record 38 of Set 6 | ginda
# Processing Record 39 of Set 6 | makakilo city
# Processing Record 40 of Set 6 | nuuk
# Processing Record 41 of Set 6 | mercedes
# Processing Record 42 of Set 6 | znamensk
# Processing Record 43 of Set 6 | markala
# Processing Record 44 of Set 6 | kenai
# Processing Record 45 of Set 6 | bargal
# Processing Record 46 of Set 6 | cabo san lucas
# Processing Record 47 of Set 6 | kathu
# Processing Record 48 of Set 6 | marawi
# Processing Record 49 of Set 6 | kyakhta
# Processing Record 50 of Set 6 | babushkin
# Processing Record 1 of Set 7 | oussouye
# Processing Record 2 of Set 7 | paramonga
# Processing Record 3 of Set 7 | mugur-aksy
# Processing Record 4 of Set 7 | college
# Processing Record 5 of Set 7 | kahului
# Processing Record 6 of Set 7 | narsaq
# Processing Record 7 of Set 7 | manzil tamim
# Processing Record 8 of Set 7 | sisimiut
# Processing Record 9 of Set 7 | saldanha
# Processing Record 10 of Set 7 | znamenskoye
# Processing Record 11 of Set 7 | kpagouda
# Processing Record 12 of Set 7 | sinnamary
# Processing Record 13 of Set 7 | mantua
# Processing Record 14 of Set 7 | huaicheng
# Processing Record 15 of Set 7 | hovd
# Processing Record 16 of Set 7 | ceres
# Processing Record 17 of Set 7 | samusu
# Processing Record 18 of Set 7 | quang ngai
# Processing Record 19 of Set 7 | beyneu
# Processing Record 20 of Set 7 | goundi
# Processing Record 21 of Set 7 | tsihombe
# Processing Record 22 of Set 7 | abu kamal
# Processing Record 23 of Set 7 | bolungarvik
# Processing Record 24 of Set 7 | aktash
# Processing Record 25 of Set 7 | kondinskoye
# Processing Record 26 of Set 7 | killybegs
# Processing Record 27 of Set 7 | riyadh
# Processing Record 28 of Set 7 | baindur
# Processing Record 29 of Set 7 | yerbogachen
# Processing Record 30 of Set 7 | durazno
# Processing Record 31 of Set 7 | bidhuna
# Processing Record 32 of Set 7 | bereda
# Processing Record 33 of Set 7 | ribeira brava
# Processing Record 34 of Set 7 | sira
# Processing Record 35 of Set 7 | luderitz
# Processing Record 36 of Set 7 | palm beach
# Processing Record 37 of Set 7 | oyem
# Processing Record 38 of Set 7 | pangnirtung
# Processing Record 39 of Set 7 | cartagena
# Processing Record 40 of Set 7 | kota belud
# Processing Record 41 of Set 7 | hojai
# Processing Record 42 of Set 7 | poroshkovo
# Processing Record 43 of Set 7 | oeiras
# Processing Record 44 of Set 7 | snasa
# Processing Record 45 of Set 7 | phan rang
# Processing Record 46 of Set 7 | bac lieu
# Processing Record 47 of Set 7 | boa vista
# Processing Record 48 of Set 7 | santa cruz
# Processing Record 49 of Set 7 | kobojango
# Processing Record 50 of Set 7 | duz
# Processing Record 1 of Set 8 | chau doc
# Processing Record 2 of Set 8 | havoysund
# Processing Record 3 of Set 8 | the valley
# Processing Record 4 of Set 8 | ayorou
# Processing Record 5 of Set 8 | altar
# Processing Record 6 of Set 8 | maceio
# Processing Record 7 of Set 8 | mahibadhoo
# Processing Record 8 of Set 8 | aras
# Processing Record 9 of Set 8 | takoradi
# Processing Record 10 of Set 8 | pochutla
# Processing Record 11 of Set 8 | wasilla
# Processing Record 12 of Set 8 | rawson
# Processing Record 13 of Set 8 | vicuna
# Processing Record 14 of Set 8 | krasnoselkup
# Processing Record 15 of Set 8 | stornoway
# Processing Record 16 of Set 8 | riberalta
# Processing Record 17 of Set 8 | vila franca do campo
# Processing Record 18 of Set 8 | fare
# Processing Record 19 of Set 8 | husavik
# Processing Record 20 of Set 8 | hornepayne
# Processing Record 21 of Set 8 | espanola
# Processing Record 22 of Set 8 | coracora
# Processing Record 23 of Set 8 | hofn
# Processing Record 24 of Set 8 | havre-saint-pierre
# Processing Record 25 of Set 8 | floro
# Processing Record 26 of Set 8 | mporokoso
# Processing Record 27 of Set 8 | meulaboh
# Processing Record 28 of Set 8 | saint-joseph
# Processing Record 29 of Set 8 | grindavik
# Processing Record 30 of Set 8 | angoche
# Processing Record 31 of Set 8 | sur
# Processing Record 32 of Set 8 | antibes
# Processing Record 33 of Set 8 | uyemskiy
# Processing Record 34 of Set 8 | teya
# Processing Record 35 of Set 8 | comodoro rivadavia
# Processing Record 36 of Set 8 | portree
# Processing Record 37 of Set 8 | starokozache
# Processing Record 38 of Set 8 | santa isabel
# Processing Record 39 of Set 8 | ganta
# Processing Record 40 of Set 8 | ormstown
# Processing Record 41 of Set 8 | xai-xai
# Processing Record 42 of Set 8 | pimentel
# Processing Record 43 of Set 8 | banikoara
# Processing Record 44 of Set 8 | promyshlennyy
# Processing Record 45 of Set 8 | xining
# Processing Record 46 of Set 8 | challans
# Processing Record 47 of Set 8 | asuncion
# Processing Record 48 of Set 8 | pischia
# Processing Record 49 of Set 8 | bugulma
# Processing Record 50 of Set 8 | bertoua
# Processing Record 1 of Set 9 | copiapo
# Processing Record 2 of Set 9 | tvoroyri
# Processing Record 3 of Set 9 | ketchikan
# Processing Record 4 of Set 9 | warqla
# Processing Record 5 of Set 9 | demyansk
# Processing Record 6 of Set 9 | ostrovnoy
# Processing Record 7 of Set 9 | mandalay
# Processing Record 8 of Set 9 | charagua
# Processing Record 9 of Set 9 | poddorye
# Processing Record 10 of Set 9 | puerto narino
# Processing Record 11 of Set 9 | jalu
# Processing Record 12 of Set 9 | veraval
# Processing Record 13 of Set 9 | kashi
# Processing Record 14 of Set 9 | parrita
# Processing Record 15 of Set 9 | altay
# Processing Record 16 of Set 9 | najran
# Processing Record 17 of Set 9 | grand river south east
# Processing Record 18 of Set 9 | ranong
# Processing Record 19 of Set 9 | camacha
# Processing Record 20 of Set 9 | longonjo
# Processing Record 21 of Set 9 | dingle
# Processing Record 22 of Set 9 | axim
# Processing Record 23 of Set 9 | hammerfest
# Processing Record 24 of Set 9 | bunda
# Processing Record 25 of Set 9 | mont-de-marsan
# Processing Record 26 of Set 9 | labuhan
# Processing Record 27 of Set 9 | balvi
# Processing Record 28 of Set 9 | filadelfia
# Processing Record 29 of Set 9 | aripuana
# Processing Record 30 of Set 9 | clyde river
# Processing Record 31 of Set 9 | lubao
# Processing Record 32 of Set 9 | khanskaya
# Processing Record 33 of Set 9 | kruisfontein
# Processing Record 34 of Set 9 | sampit
# Processing Record 35 of Set 9 | qaqortoq
# Processing Record 36 of Set 9 | monte alegre
# Processing Record 37 of Set 9 | kristiansund
# Processing Record 38 of Set 9 | prior lake
# Processing Record 39 of Set 9 | shaartuz
# Processing Record 40 of Set 9 | sarai alamgir
# Processing Record 41 of Set 9 | mao
# Processing Record 42 of Set 9 | accra
# Processing Record 43 of Set 9 | fort nelson
# Processing Record 44 of Set 9 | berlevag
# Processing Record 45 of Set 9 | caraballeda
# Processing Record 46 of Set 9 | kutum
# Processing Record 47 of Set 9 | mandalgovi
# Processing Record 48 of Set 9 | salisbury
# Processing Record 49 of Set 9 | karymskoye
# Processing Record 50 of Set 9 | coihaique
# Processing Record 1 of Set 10 | plettenberg bay
# Processing Record 2 of Set 10 | tapa
# Processing Record 3 of Set 10 | coulihaut
# Processing Record 4 of Set 10 | moose factory
# Processing Record 5 of Set 10 | lagunas
# Processing Record 6 of Set 10 | tokmak
# Processing Record 7 of Set 10 | sao joao dos patos
# Processing Record 8 of Set 10 | armacao dos buzios
# Processing Record 9 of Set 10 | cuamba
# Processing Record 10 of Set 10 | coquimbo
# Processing Record 11 of Set 10 | juarez
# Processing Record 12 of Set 10 | kananga
# Processing Record 13 of Set 10 | rapid valley
# Processing Record 14 of Set 10 | brigantine
# Processing Record 15 of Set 10 | fortuna
# Processing Record 16 of Set 10 | aykhal
# Processing Record 17 of Set 10 | kostomuksha
# Processing Record 18 of Set 10 | lahad datu
# Processing Record 19 of Set 10 | chernyshevskiy
# Processing Record 20 of Set 10 | gerash
# Processing Record 21 of Set 10 | kerki
# Processing Record 22 of Set 10 | la ronge
# Processing Record 23 of Set 10 | yar-sale
# Processing Record 24 of Set 10 | cehegin
# Processing Record 25 of Set 10 | baherden
# Processing Record 26 of Set 10 | raga
# Processing Record 27 of Set 10 | khilchipur
# Processing Record 28 of Set 10 | cozumel
# Processing Record 29 of Set 10 | salym
# Processing Record 30 of Set 10 | torrington
# Processing Record 31 of Set 10 | umm lajj
# Processing Record 32 of Set 10 | grand-santi
# Processing Record 33 of Set 10 | palembang
# Processing Record 34 of Set 10 | barinitas
# Processing Record 35 of Set 10 | roquetas de mar
# Processing Record 36 of Set 10 | vaasa
# Processing Record 37 of Set 10 | egvekinot
# Processing Record 38 of Set 10 | polunochnoye
# Processing Record 39 of Set 10 | clarence town
# Processing Record 40 of Set 10 | epe
# Processing Record 41 of Set 10 | general roca
# Processing Record 42 of Set 10 | cullen
# Processing Record 43 of Set 10 | arya
# Processing Record 44 of Set 10 | flin flon
# Processing Record 45 of Set 10 | lucapa
# Processing Record 46 of Set 10 | port-gentil
# Processing Record 47 of Set 10 | razole
# Processing Record 48 of Set 10 | linares
# Processing Record 49 of Set 10 | oranjemund
# Processing Record 50 of Set 10 | leh
# Processing Record 1 of Set 11 | jam sahib
# Processing Record 2 of Set 11 | kavaratti
# Processing Record 3 of Set 11 | bodden town
# Processing Record 4 of Set 11 | wamba
# Processing Record 5 of Set 11 | salsomaggiore terme
# Processing Record 6 of Set 11 | saint-ambroise
# Processing Record 7 of Set 11 | dolbeau
# Processing Record 8 of Set 11 | hof
# Processing Record 9 of Set 11 | belyy yar
# Processing Record 10 of Set 11 | vangaindrano
# Processing Record 11 of Set 11 | bulungu
# Processing Record 12 of Set 11 | utrecht
# Processing Record 13 of Set 11 | kozan
# Processing Record 14 of Set 11 | caidian
# Processing Record 15 of Set 11 | eureka
# Processing Record 16 of Set 11 | tlahualilo
# Processing Record 17 of Set 11 | asyut
# Processing Record 18 of Set 11 | ambilobe
# Processing Record 19 of Set 11 | whitehorse
# Processing Record 20 of Set 11 | wajid
# Processing Record 21 of Set 11 | kyshtovka
# Processing Record 22 of Set 11 | la palma
# Processing Record 23 of Set 11 | douentza
# Processing Record 24 of Set 11 | portel
# Processing Record 25 of Set 11 | corinto
# Processing Record 26 of Set 11 | palabuhanratu
# Processing Record 27 of Set 11 | turka
# Processing Record 28 of Set 11 | porto velho
# Processing Record 29 of Set 11 | samoded
# Processing Record 30 of Set 11 | san andres
# Processing Record 31 of Set 11 | pacific grove
# Processing Record 32 of Set 11 | nome
# Processing Record 33 of Set 11 | bocas del toro
# Processing Record 34 of Set 11 | mecca
# Processing Record 35 of Set 11 | tura
# Processing Record 36 of Set 11 | faya
# Processing Record 37 of Set 11 | wattegama
# Processing Record 38 of Set 11 | alampur
# Processing Record 39 of Set 11 | baiyin
# Processing Record 40 of Set 11 | dudinka
# Processing Record 41 of Set 11 | martapura
# Processing Record 42 of Set 11 | koshurnikovo
# Processing Record 43 of Set 11 | solano
# Processing Record 44 of Set 11 | lethem
# Processing Record 45 of Set 11 | chistogorskiy
# Processing Record 46 of Set 11 | suez
# Processing Record 47 of Set 11 | pangody
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
new_column_order = ["column2", "column4", "column1"]
city_data_df.head(10)
# Out:
#              City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0           Vaini  26.2958  68.6292      69.8        68           3
# 1     Port Alfred  26.2958  68.6292      69.8        68           3
# 2            Hilo  26.2958  68.6292      69.8        68           3
# 3   Mar Del Plata  26.2958  68.6292      69.8        68           3
# 4         Qaanaaq  26.2958  68.6292      69.8        68           3
# 5        Hermanus  26.2958  68.6292      69.8        68           3
# 6          Palmer  26.2958  68.6292      69.8        68           3
# 7   Cristinapolis  26.2958  68.6292      69.8        68           3
# 8    Todos Santos  26.2958  68.6292      69.8        68           3
# 9  Saint-Augustin  26.2958  68.6292      69.8        68           3
#
#    Wind Speed Country                 Date
# 0        4.61      PK  2021-04-05 00:36:10
# 1        4.61      PK  2021-04-05 00:36:10
# 2        4.61      PK  2021-04-05 00:36:10
# 3        4.61      PK  2021-04-05 00:36:10
# 4        4.61      PK  2021-04-05 00:36:10
# 5        4.61      PK  2021-04-05 00:36:10
# 6        4.61      PK  2021-04-05 00:36:10
# 7        4.61      PK  2021-04-05 00:36:10
# 8        4.61      PK  2021-04-05 00:36:10
# 9        4.61      PK  2021-04-05 00:36:10

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-25-4656af7b4f5d> in <module>
#       2 output_data_file = "weather_data/WeatherPy_Database.csv"
#       3 # Export the City_Data into a CSV.
# ----> 4 city_data_df.to_csv(output_data_file, index_label="City_ID")
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors)
#    3168             decimal=decimal,
#    3169         )
# -> 3170         formatter.save()
#    3171
#    3172         if path_or_buf is None:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     183             close = False
#     184         else:
# --> 185             f, handles = get_handle(
#     186                 self.path_or_buf,
#     187                 self.mode,
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors)
#     491         if encoding:
#     492             # Encoding
# --> 493             f = open(path_or_buf, mode, encoding=encoding, errors=errors, newline="")
#     494         elif is_text:
#     495             # No explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'weather_data/WeatherPy_Database.csv'
